# %%
import os
os.chdir(os.path.join(os.getcwd(), '..'))
os.getcwd()
# Out:
# '/home/renjie/Documents/MTech/AY1819Sem1/KE5208_SenseMakingAndInsightsDiscovery/CA'

# %%
from src.utils import get_dataset
from src.utils import select_data

import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

from keras.utils import to_categorical
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Bidirectional
from keras.layers import Dropout
from keras.optimizers import Adam
from keras.callbacks import TensorBoard
from keras.callbacks import ModelCheckpoint
# Out:
# /home/renjie/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
DATA_PATH = os.path.join(os.getcwd(), 'data')
os.listdir(DATA_PATH)
# Out:
# ['Depth', 'Inertial', 'Skeleton', 'RGB']

# %%
depth_path, inertial_path, skeleton_path,rgb_path = get_dataset(DATA_PATH)

# %%
activities = list(range(1,28))

# %%
def select_subject(d_path, subject):
    select_statement = '_s{}_'.format(subject)
    subjects = []
    for i in d_path:
        if select_statement in i:
            subjects.append(i)
    return subjects

# %%
def get_action_number(single_path):
    return int(single_path.split('/')[-1].split('_')[0][1:])
def get_subject_number(single_path):
    return int(single_path.split('/')[-1].split('_')[1][1:])
def get_trial_number(single_path):
    return int(single_path.split('/')[-1].split('_')[2][1:])

# %%
def pad_len_inertial(inertial_d):
    inertial_d = np.swapaxes(inertial_d, 0,1)
    inertial_d = sequence.pad_sequences(inertial_d, maxlen=326)
    inertial_d = np.swapaxes(inertial_d, 0,1)
    return inertial_d

# %%
# train on subject 1,2,3,5,6,7
# test on subject 4,8
X_train = []
Y_train = []
X_test = []
Y_test = []

for path in inertial_path:
    if get_subject_number(path) in [1,3,5,7]:
        X_train.append(path)
        Y_train.append(get_action_number(path))
    else:
        X_test.append(path)
        Y_test.append(get_action_number(path))

X_train = [pad_len_inertial(sio.loadmat(x)['d_iner']) for x in X_train]
X_test = [pad_len_inertial(sio.loadmat(x)['d_iner']) for x in X_test]

X_train = np.array(X_train)
X_test = np.array(X_test)

Y_train = to_categorical(np.array(Y_train) - 1)
Y_test = to_categorical(np.array(Y_test) - 1)

X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((431, 326, 6), (431, 27), (430, 326, 6), (430, 27))

# %% [markdown]
# # Model

# %%
import keras.backend as K


def f1(y_true, y_pred):
    '''
    Calculates the F1 by using keras.backend
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))

    def recall(y_true, y_pred):
        """Recall metric.
        Only computes a batch-wise average of recall.
        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.
        Only computes a batch-wise average of precision.
        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
#     print("precision: ", precision)
#     print("recall: ", recall)
    return 2 * ((precision * recall) / (precision + recall))

# %%
# def simple_LSTM():
#     np.random.seed(7)
#     model = Sequential(name = 'simple_LSTM')
#     model.add(LSTM(100, input_shape=(326, 6)))
#     model.add(Dense(len(activities), activation='softmax'))
#     model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=1e-3), metrics=['accuracy', 'mse',f1])
#     print(model.summary())
#     return model

# %%
def bidirectional_LSTM():
    np.random.seed(7)
    model = Sequential(name = 'bidirectional_LSTM')
    model.add(Bidirectional(LSTM(50), input_shape=(326, 6)))
    model.add(Dropout(0.5))
    model.add(Dense(len(activities), activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=1e-3), metrics=['accuracy', 'mse',f1])
    print(model.summary())
    return model

# %%
# model = simple_LSTM()

# %%
model = bidirectional_LSTM()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 100)               22800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 27)                2727
# =================================================================
# Total params: 25,527
# Trainable params: 25,527
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
LOG_DIR = os.path.join(os.getcwd(), 'logs')
tb = TensorBoard(LOG_DIR)

# %%
weights_dir = 'weights/' + model.name + \
            '-{epoch:02d}-{loss:.2f}.hdf5'
chkpt = ModelCheckpoint(filepath=weights_dir, monitor='loss', save_best_only=True, save_weights_only=True, mode='auto', period=1)

# %%
history = history = model.fit(X_train, Y_train, epochs=50, batch_size=4, validation_data = (X_test, Y_test), callbacks=[tb, chkpt])
# Out:
# Train on 431 samples, validate on 430 samples
# Epoch 1/50
# 431/431 [==============================] - 26s 61ms/step - loss: 3.3649 - acc: 0.0441 - mean_squared_error: 0.0359 - f1: nan - val_loss: 3.3008 - val_acc: 0.0535 - val_mean_squared_error: 0.0357 - val_f1: nan
# Epoch 2/50
# 431/431 [==============================] - 35s 80ms/step - loss: 3.2346 - acc: 0.0766 - mean_squared_error: 0.0355 - f1: nan - val_loss: 3.2693 - val_acc: 0.0791 - val_mean_squared_error: 0.0356 - val_f1: nan
# Epoch 3/50
# 431/431 [==============================] - 36s 84ms/step - loss: 3.1651 - acc: 0.0998 - mean_squared_error: 0.0352 - f1: nan - val_loss: 3.2206 - val_acc: 0.0837 - val_mean_squared_error: 0.0354 - val_f1: nan
# Epoch 4/50
# 431/431 [==============================] - 39s 90ms/step - loss: 3.0213 - acc: 0.1369 - mean_squared_error: 0.0347 - f1: nan - val_loss: 3.1314 - val_acc: 0.0907 - val_mean_squared_error: 0.0350 - val_f1: nan
# Epoch 5/50
# 431/431 [==============================] - 25s 59ms/step - loss: 2.9065 - acc: 0.1299 - mean_squared_error: 0.0343 - f1: nan - val_loss: 3.0535 - val_acc: 0.0953 - val_mean_squared_error: 0.0348 - val_f1: nan
# Epoch 6/50
# 431/431 [==============================] - 26s 60ms/step - loss: 2.7275 - acc: 0.1810 - mean_squared_error: 0.0334 - f1: nan - val_loss: 3.0093 - val_acc: 0.1209 - val_mean_squared_error: 0.0346 - val_f1: nan
# Epoch 7/50
# 431/431 [==============================] - 25s 59ms/step - loss: 2.6906 - acc: 0.1995 - mean_squared_error: 0.0334 - f1: nan - val_loss: 3.0844 - val_acc: 0.1233 - val_mean_squared_error: 0.0349 - val_f1: nan
# Epoch 8/50
# 431/431 [==============================] - 25s 58ms/step - loss: 2.5563 - acc: 0.2390 - mean_squared_error: 0.0327 - f1: nan - val_loss: 2.9662 - val_acc: 0.1209 - val_mean_squared_error: 0.0345 - val_f1: nan
# Epoch 9/50
# 431/431 [==============================] - 25s 59ms/step - loss: 2.4840 - acc: 0.2181 - mean_squared_error: 0.0321 - f1: nan - val_loss: 2.9288 - val_acc: 0.1186 - val_mean_squared_error: 0.0343 - val_f1: nan
# Epoch 10/50
# 431/431 [==============================] - 25s 59ms/step - loss: 2.3966 - acc: 0.2575 - mean_squared_error: 0.0316 - f1: nan - val_loss: 2.9321 - val_acc: 0.1279 - val_mean_squared_error: 0.0343 - val_f1: nan
# Epoch 11/50
# 431/431 [==============================] - 27s 63ms/step - loss: 2.3780 - acc: 0.2367 - mean_squared_error: 0.0315 - f1: nan - val_loss: 2.9193 - val_acc: 0.1326 - val_mean_squared_error: 0.0343 - val_f1: nan
# Epoch 12/50
# 431/431 [==============================] - 31s 71ms/step - loss: 2.3823 - acc: 0.2854 - mean_squared_error: 0.0316 - f1: nan - val_loss: 2.9621 - val_acc: 0.1256 - val_mean_squared_error: 0.0345 - val_f1: nan
# Epoch 13/50
50
# 431/431 [==============================] - 26s 61ms/step - loss: 1.2625 - acc: 0.6311 - mean_squared_error: 0.0198 - f1: nan - val_loss: 3.3766 - val_acc: 0.1605 - val_mean_squared_error: 0.0367 - val_f1: nan
# Epoch 43/50
# 431/431 [==============================] - 27s 62ms/step - loss: 1.1870 - acc: 0.6450 - mean_squared_error: 0.0190 - f1: nan - val_loss: 3.3918 - val_acc: 0.1488 - val_mean_squared_error: 0.0369 - val_f1: nan
# Epoch 44/50
# 431/431 [==============================] - 26s 61ms/step - loss: 1.1600 - acc: 0.6520 - mean_squared_error: 0.0186 - f1: nan - val_loss: 3.4706 - val_acc: 0.1512 - val_mean_squared_error: 0.0373 - val_f1: nan
# Epoch 45/50
# 431/431 [==============================] - 27s 62ms/step - loss: 1.1871 - acc: 0.6450 - mean_squared_error: 0.0189 - f1: nan - val_loss: 3.4770 - val_acc: 0.1419 - val_mean_squared_error: 0.0379 - val_f1: nan
# Epoch 46/50
# 431/431 [==============================] - 26s 61ms/step - loss: 1.2201 - acc: 0.6450 - mean_squared_error: 0.0193 - f1: nan - val_loss: 3.5616 - val_acc: 0.1163 - val_mean_squared_error: 0.0383 - val_f1: nan
# Epoch 47/50
# 431/431 [==============================] - 26s 61ms/step - loss: 1.2305 - acc: 0.6172 - mean_squared_error: 0.0195 - f1: nan - val_loss: 3.5838 - val_acc: 0.1209 - val_mean_squared_error: 0.0383 - val_f1: nan
# Epoch 48/50
# 431/431 [==============================] - 26s 61ms/step - loss: 1.1510 - acc: 0.6473 - mean_squared_error: 0.0181 - f1: nan - val_loss: 3.5795 - val_acc: 0.1488 - val_mean_squared_error: 0.0382 - val_f1: nan
# Epoch 49/50
# 431/431 [==============================] - 26s 61ms/step - loss: 1.1232 - acc: 0.6682 - mean_squared_error: 0.0180 - f1: nan - val_loss: 3.5242 - val_acc: 0.1558 - val_mean_squared_error: 0.0379 - val_f1: nan
# Epoch 50/50
# 431/431 [==============================] - 26s 61ms/step - loss: 1.0867 - acc: 0.6845 - mean_squared_error: 0.0170 - f1: nan - val_loss: 3.5366 - val_acc: 0.1581 - val_mean_squared_error: 0.0376 - val_f1: nan

# %% [markdown]
# # Evaluation

# %%
train_acc = history.history['acc']
val_acc = history.history['val_acc']
plt.plot(train_acc, 'C0')
plt.plot(val_acc, 'C1')
plt.show()

# %%
model.evaluate(X_train, Y_train)
# Out:
# 431/431 [==============================] - 1s 2ms/step
# [0.7268636544729883,
#  0.8584686783239626,
#  0.011599691895867445,
#  0.7317185929507501]

# %%
model.evaluate(X_test, Y_test)
# Out:
# 430/430 [==============================] - 1s 2ms/step
# [3.536637214172718, 0.15813953498768252, 0.037642297737820206, nan]

# %%
pred_1 = np.argmax(model.predict(X_train), axis = -1)

# %%
class_labels = ['swipe to the left',
               'swipe to the right',
               'wave',
               'front clap',
               'throw',
               'cross arms',
               'basketball shoot',
               'draw x',
               'draw circle (CW)',
               'draw circle (CCW)',
               'draw triangle',
               'bowling',
               'boxing',
               'baseball swing',
               'tennis swing',
               'arm curl',
               'tennis serve',
               'two hand push',
               'knock door',
               'catch',
               'pick and throw',
               'jogging',qst
               'walking',
               'sit to stand',
               'stand to sit',
               'forward lunge',
               'squat']

# %%
confusion_1 = confusion_matrix(np.argmax(Y_train, axis = -1), pred_1)
NUM_LABELS = 27

f, axes = plt.subplots(1,1, figsize = (12,12))
axes.set_xlabel('Actual')
axes.set_ylabel('Predicted')
axes.grid(False)
axes.set_xticklabels(class_labels, rotation = 90)
axes.set_yticklabels(class_labels)
axes.set_yticks(list(range(27)))
axes.set_xticks(list(range(27)))
plt.imshow(confusion_1, cmap=plt.cm.Set2, interpolation='nearest')

for i, cas in enumerate(confusion_1):
    for j, count in enumerate(cas):
        if count > 0:
            xoff = .07 * len(str(count))
            plt.text(j-xoff, i+.2, int(count), fontsize=12, color='black')

# %% [markdown]
# # Seeing if there is a bug

# %%
for i in range(len(inertial_path)):
    test = sio.loadmat(inertial_path[i])['d_iner']
    test = np.expand_dims(np.swapaxes(sequence.pad_sequences(np.swapaxes(test,1,0), maxlen= 326), 1, 0), axis =0)
    pred = model.predict(test)
    print('Predicted: {} Expected: [{}]'.format(np.argmax(pred, axis = -1) + 1, get_action_number(inertial_path[i])))
# Out:
# Predicted: [1] Expected: [1]
# Predicted: [1] Expected: [1]
# Predicted: [1] Expected: [1]
# Predicted: [1] Expected: [1]
# Predicted: [17] Expected: [1]
# Predicted: [20] Expected: [1]
# Predicted: [16] Expected: [1]
# Predicted: [20] Expected: [1]
# Predicted: [1] Expected: [1]
# Predicted: [13] Expected: [1]
# Predicted: [5] Expected: [1]
# Predicted: [3] Expected: [1]
# Predicted: [3] Expected: [1]
# Predicted: [17] Expected: [1]
# Predicted: [21] Expected: [1]
# Predicted: [14] Expected: [1]
# Predicted: [1] Expected: [1]
# Predicted: [1] Expected: [1]
# Predicted: [1] Expected: [1]
# Predicted: [1] Expected: [1]
# Predicted: [6] Expected: [1]
# Predicted: [6] Expected: [1]
# Predicted: [13] Expected: [1]
# Predicted: [5] Expected: [1]
# Predicted: [1] Expected: [1]
# Predicted: [1] Expected: [1]
# Predicted: [12] Expected: [1]
# Predicted: [1] Expected: [1]
# Predicted: [6] Expected: [1]
# Predicted: [6] Expected: [1]
# Predicted: [12] Expected: [1]
# Predicted: [3] Expected: [1]
# Predicted: [2] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [6] Expected: [2]
# Predicted: [19] Expected: [2]
# Predicted: [10] Expected: [2]
# Predicted: [20] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [4] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [5] Expected: [2]
# Predicted: [6] Expected: [2]
# Predicted: [4] Expected: [2]
# Predicted: [16] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [13] Expected: [2]
# Predicted: [6] Expected: [2]
# Predicted: [11] Expected: [2]
# Predicted: [21] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [2] Expected: [2]
# Predicted: [6] Expected: [2]
# Predicted: [6] Expected: [2]
# Predicted: [6] Expected: [2]
# Predicted: [12] Expected: [2]
# Predicted: [3] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [15] Expected: [3]
# Predicted: [1] Expected: [3]
# Predicted: [16] Expected: [3]
# Predicted: [13] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [5] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [12] Expected: [3]
# Predicted: [6] Expected: [3]
# Predicted: [15] Expected: [3]
# Predicted: [8] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [5] Expected: [3]
# Predicted: [18] Expected: [3]
# Predicted: [5] Expected: [3]
# Predicted: [5] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [19] Expected: [3]
# Predicted: [3] Expected: [3]
# Predicted: [5] Expected: [3]
# Predicted: [12] Expected: [3]
# Predicted: [13] Expected: [3]
# Predicted: [5] Expected: [3]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [14] Expected: [4]
# Predicted: [14] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [13] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [8] Expected: [4]
# Predicted: [7] Expected: [4]
# Predicted: [16] Expected: [4]
# Predicted: [17] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [3] Expected: [4]
# Predicted: [16] Expected: [4]
# Predicted: [6] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [26] Expected: [4]
# Predicted: [22] Expected: [4]
# Predicted: [4] Expected: [4]
# Predicted: [11] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [21] Expected: [5]
# Predicted: [20] Expected: [5]
# Predicted: [10] Expected: [5]
# Predicted: [3] Expected: [5]
# Predicted: [20] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [3] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [21] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [18] Expected: [5]
# Predicted: [15] Expected: [5]
# Predicted: [14] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [16] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [5] Expected: [5]
# Predicted: [19] Expected: [5]
# Predicted: [4] Expected: [5]
# Predicted: [6] Expected: [5]
# Predicted: [8] Expected: [5]
# Predicted: [22] Expected: [5]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [14] Expected: [6]
# Predicted: [9] Expected: [6]
# Predicted: [20] Expected: [6]
# Predicted: [10] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [16] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [1] Expected: [6]
# Predicted: [22] Expected: [6]
# Predicted: [12] Expected: [6]
# Predicted: [22] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [4] Expected: [6]
# Predicted: [17] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [4] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [6] Expected: [6]
# Predicted: [4] Expected: [6]
# Predicted: [7] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [6] Expected: [7]
# Predicted: [11] Expected: [7]
# Predicted: [19] Expected: [7]
# Predicted: [11] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [5] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [21] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [4] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [19] Expected: [7]
# Predicted: [13] Expected: [7]
# Predicted: [13] Expected: [7]
# Predicted: [3] Expected: [7]
# Predicted: [5] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [7] Expected: [7]
# Predicted: [12] Expected: [7]
# Predicted: [1] Expected: [7]
# Predicted: [16] Expected: [7]
# Predicted: [26] Expected: [7]
# Predicted: [9] Expected: [8]
# Predicted: [8] Expected: [8]
# Predicted: [8] Expected: [8]
# Predicted: [7] Expected: [8]
# Predicted: [9] Expected: [8]
# Predicted: [13] Expected: [8]
# Predicted: [20] Expected: [8]
# Predicted: [8] Expected: [8]
# Predicted: [2] Expected: [8]
# Predicted: [8] Expected: [8]
# Predicted: [13] Expected: [8]
# Predicted: [22] Expected: [8]
# Predicted: [6] Expected: [8]
# Predicted: [6] Expected: [8]
# Predicted: [15] Expected: [8]
# Predicted: [8] Expected: [8]
# Predicted: [8] Expected: [8]
# Predicted: [8] Expected: [8]
# Predicted: [8] Expected: [8]
# Predicted: [2] Expected: [8]
# Predicted: [3] Expected: [8]
# Predicted: [5] Expected: [8]
# Predicted: [15] Expected: [8]
# Predicted: [8] Expected: [8]
# Predicted: [11] Expected: [8]
# Predicted: [8] Expected: [8]
# Predicted: [11] Expected: [8]
# Predicted: [3] Expected: [8]
# Predicted: [3] Expected: [8]
# Predicted: [7] Expected: [8]
# Predicted: [5] Expected: [8]
# Predicted: [9] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [20] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [16] Expected: [9]
# Predicted: [17] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [4] Expected: [9]
# Predicted: [12] Expected: [9]
# Predicted: [3] Expected: [9]
# Predicted: [5] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [15] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [3] Expected: [9]
# Predicted: [21] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [9] Expected: [9]
# Predicted: [10] Expected: [9]
# Predicted: [4] Expected: [9]
# Predicted: [26] Expected: [9]
# Predicted: [13] Expected: [9]
# Predicted: [8] Expected: [9]
# Predicted: [10] Expected: [10]
# Predicted: [10] Expected: [10]
# Predicted: [10] Expected: [10]
# Predicted: [9] Expected: [10]
# Predicted: [20] Expected: [10]
# Predicted: [20] Expected: [10]
# Predicted: [20] Expected: [10]
# Predicted: [9] Expected: [10]
# Predicted: [2] Expected: [10]
# Predicted: [10] Expected: [10]
# Predicted: [10] Expected: [10]
# Predicted: [10] Expected: [10]
# Predicted: [6] Expected: [10]
# Predicted: [1] Expected: [10]
# Predicted: [3] Expected: [10]
# Predicted: [5] Expected: [10]
# Predicted: [4] Expected: [10]
# Predicted: [10] Expected: [10]
# Predicted: [10] Expected: [10]
# Predicted: [10] Expected: [10]
# Predicted: [13] Expected: [10]
# Predicted: [17] Expected: [10]
# Predicted: [12] Expected: [10]
# Predicted: [11] Expected: [10]
# Predicted: [10] Expected: [10]
# Predicted: [10] Expected: [10]
# Predicted: [10] Expected: [10]
# Predicted: [10] Expected: [10]
# Predicted: [4] Expected: [10]
# Predicted: [12] Expected: [10]
# Predicted: [13] Expected: [10]
# Predicted: [14] Expected: [10]
# Predicted: [11] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [1] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [20] Expected: [11]
# Predicted: [7] Expected: [11]
# Predicted: [20] Expected: [11]
# Predicted: [20] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [20] Expected: [11]
# Predicted: [23] Expected: [11]
# Predicted: [12] Expected: [11]
# Predicted: [3] Expected: [11]
# Predicted: [4] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [18] Expected: [11]
# Predicted: [13] Expected: [11]
# Predicted: [5] Expected: [11]
# Predicted: [13] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [11] Expected: [11]
# Predicted: [5] Expected: [11]
# Predicted: [4] Expected: [11]
# Predicted: [4] Expected: [11]
# Predicted: [6] Expected: [11]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [16] Expected: [12]
# Predicted: [22] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [26] Expected: [12]
# Predicted: [16] Expected: [12]
# Predicted: [22] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [16] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [6] Expected: [12]
# Predicted: [22] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [12] Expected: [12]
# Predicted: [23] Expected: [12]
# Predicted: [26] Expected: [12]
# Predicted: [6] Expected: [12]
# Predicted: [13] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [18] Expected: [13]
# Predicted: [7] Expected: [13]
# Predicted: [6] Expected: [13]
# Predicted: [19] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [16] Expected: [13]
# Predicted: [22] Expected: [13]
# Predicted: [6] Expected: [13]
# Predicted: [1] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [19] Expected: [13]
# Predicted: [8] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [15] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [15] Expected: [13]
# Predicted: [3] Expected: [13]
# Predicted: [5] Expected: [13]
# Predicted: [20] Expected: [13]
# Predicted: [6] Expected: [13]
# Predicted: [13] Expected: [13]
# Predicted: [14] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [19] Expected: [14]
# Predicted: [6] Expected: [14]
# Predicted: [13] Expected: [14]
# Predicted: [15] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [17] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [6] Expected: [14]
# Predicted: [6] Expected: [14]
# Predicted: [6] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [21] Expected: [14]
# Predicted: [20] Expected: [14]
# Predicted: [12] Expected: [14]
# Predicted: [10] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [17] Expected: [14]
# Predicted: [14] Expected: [14]
# Predicted: [6] Expected: [14]
# Predicted: [26] Expected: [14]
# Predicted: [12] Expected: [14]
# Predicted: [22] Expected: [14]
# Predicted: [15] Expected: [15]
# Predicted: [15] Expected: [15]
# Predicted: [15] Expected: [15]
# Predicted: [15] Expected: [15]
# Predicted: [5] Expected: [15]
# Predicted: [17] Expected: [15]
# Predicted: [20] Expected: [15]
# Predicted: [19] Expected: [15]
# Predicted: [15] Expected: [15]
# Predicted: [15] Expected: [15]
# Predicted: [15] Expected: [15]
# Predicted: [17] Expected: [15]
# Predicted: [11] Expected: [15]
# Predicted: [6] Expected: [15]
# Predicted: [16] Expected: [15]
# Predicted: [14] Expected: [15]
# Predicted: [21] Expected: [15]
# Predicted: [15] Expected: [15]
# Predicted: [15] Expected: [15]
# Predicted: [15] Expected: [15]
# Predicted: [12] Expected: [15]
# Predicted: [17] Expected: [15]
# Predicted: [4] Expected: [15]
# Predicted: [13] Expected: [15]
# Predicted: [15] Expected: [15]
# Predicted: [15] Expected: [15]
# Predicted: [16] Expected: [15]
# Predicted: [15] Expected: [15]
# Predicted: [26] Expected: [15]
# Predicted: [7] Expected: [15]
# Predicted: [12] Expected: [15]
# Predicted: [14] Expected: [15]
# Predicted: [16] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [21] Expected: [16]
# Predicted: [9] Expected: [16]
# Predicted: [20] Expected: [16]
# Predicted: [6] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [4] Expected: [16]
# Predicted: [22] Expected: [16]
# Predicted: [4] Expected: [16]
# Predicted: [7] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [5] Expected: [16]
# Predicted: [17] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [13] Expected: [16]
# Predicted: [15] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [16] Expected: [16]
# Predicted: [4] Expected: [16]
# Predicted: [26] Expected: [16]
# Predicted: [22] Expected: [16]
# Predicted: [22] Expected: [16]
# Predicted: [17] Expected: [17]
# Predicted: [17] Expected: [17]
# Predicted: [17] Expected: [17]
# Predicted: [17] Expected: [17]
# Predicted: [19] Expected: [17]
# Predicted: [6] Expected: [17]
# Predicted: [7] Expected: [17]
# Predicted: [13] Expected: [17]
# Predicted: [17] Expected: [17]
# Predicted: [21] Expected: [17]
# Predicted: [17] Expected: [17]
# Predicted: [19] Expected: [17]
# Predicted: [15] Expected: [17]
# Predicted: [16] Expected: [17]
# Predicted: [6] Expected: [17]
# Predicted: [8] Expected: [17]
# Predicted: [17] Expected: [17]
# Predicted: [17] Expected: [17]
# Predicted: [17] Expected: [17]
# Predicted: [17] Expected: [17]
# Predicted: [6] Expected: [17]
# Predicted: [11] Expected: [17]
# Predicted: [15] Expected: [17]
# Predicted: [20] Expected: [17]
# Predicted: [17] Expected: [17]
# Predicted: [17] Expected: [17]
# Predicted: [17] Expected: [17]
# Predicted: [14] Expected: [17]
# Predicted: [22] Expected: [17]
# Predicted: [12] Expected: [17]
# Predicted: [12] Expected: [17]
# Predicted: [8] Expected: [17]
# Predicted: [18] Expected: [18]
# Predicted: [1] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [1] Expected: [18]
# Predicted: [11] Expected: [18]
# Predicted: [12] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [12] Expected: [18]
# Predicted: [12] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [13] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [10] Expected: [18]
# Predicted: [6] Expected: [18]
# Predicted: [11] Expected: [18]
# Predicted: [12] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [19] Expected: [18]
# Predicted: [18] Expected: [18]
# Predicted: [3] Expected: [18]
# Predicted: [22] Expected: [18]
# Predicted: [1] Expected: [18]
# Predicted: [4] Expected: [18]
# Predicted: [6] Expected: [18]
# Predicted: [19] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [20] Expected: [19]
# Predicted: [9] Expected: [19]
# Predicted: [6] Expected: [19]
# Predicted: [15] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [6] Expected: [19]
# Predicted: [4] Expected: [19]
# Predicted: [1] Expected: [19]
# Predicted: [13] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [16] Expected: [19]
# Predicted: [6] Expected: [19]
# Predicted: [13] Expected: [19]
# Predicted: [17] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [17] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [13] Expected: [19]
# Predicted: [19] Expected: [19]
# Predicted: [4] Expected: [19]
# Predicted: [18] Expected: [19]
# Predicted: [20] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [11] Expected: [20]
# Predicted: [9] Expected: [20]
# Predicted: [15] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [5] Expected: [20]
# Predicted: [5] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [15] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [15] Expected: [20]
# Predicted: [13] Expected: [20]
# Predicted: [14] Expected: [20]
# Predicted: [5] Expected: [20]
# Predicted: [19] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [20] Expected: [20]
# Predicted: [19] Expected: [20]
# Predicted: [2] Expected: [20]
# Predicted: [1] Expected: [20]
# Predicted: [2] Expected: [20]
# Predicted: [9] Expected: [20]
# Predicted: [21] Expected: [21]
# Predicted: [21] Expected: [21]
# Predicted: [5] Expected: [21]
# Predicted: [21] Expected: [21]
# Predicted: [9] Expected: [21]
# Predicted: [20] Expected: [21]
# Predicted: [4] Expected: [21]
# Predicted: [9] Expected: [21]
# Predicted: [5] Expected: [21]
# Predicted: [21] Expected: [21]
# Predicted: [21] Expected: [21]
# Predicted: [21] Expected: [21]
# Predicted: [16] Expected: [21]
# Predicted: [11] Expected: [21]
# Predicted: [11] Expected: [21]
# Predicted: [1] Expected: [21]
# Predicted: [21] Expected: [21]
# Predicted: [17] Expected: [21]
# Predicted: [14] Expected: [21]
# Predicted: [21] Expected: [21]
# Predicted: [9] Expected: [21]
# Predicted: [18] Expected: [21]
# Predicted: [13] Expected: [21]
# Predicted: [13] Expected: [21]
# Predicted: [21] Expected: [21]
# Predicted: [16] Expected: [21]
# Predicted: [19] Expected: [21]
# Predicted: [21] Expected: [21]
# Predicted: [2] Expected: [21]
# Predicted: [4] Expected: [21]
# Predicted: [3] Expected: [21]
# Predicted: [8] Expected: [21]
# Predicted: [22] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [14] Expected: [22]
# Predicted: [12] Expected: [22]
# Predicted: [12] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [26] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [26] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [4] Expected: [22]
# Predicted: [23] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [23] Expected: [22]
# Predicted: [9] Expected: [22]
# Predicted: [12] Expected: [22]
# Predicted: [12] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [27] Expected: [22]
# Predicted: [22] Expected: [22]
# Predicted: [26] Expected: [22]
# Predicted: [23] Expected: [22]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [22] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [26] Expected: [23]
# Predicted: [22] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [22] Expected: [23]
# Predicted: [27] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [16] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [16] Expected: [23]
# Predicted: [22] Expected: [23]
# Predicted: [22] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [24] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [23] Expected: [23]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [27] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [23] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [27] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [25] Expected: [24]
# Predicted: [23] Expected: [24]
# Predicted: [24] Expected: [24]
# Predicted: [25] Expected: [24]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [24] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [24] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [24] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [24] Expected: [25]
# Predicted: [27] Expected: [25]
# Predicted: [24] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [27] Expected: [25]
# Predicted: [24] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [25] Expected: [25]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [24] Expected: [26]
# Predicted: [23] Expected: [26]
# Predicted: [23] Expected: [26]
# Predicted: [22] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [22] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [22] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [6] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [23] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [23] Expected: [26]
# Predicted: [23] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [26] Expected: [26]
# Predicted: [27] Expected: [27]
# Predicted: [24] Expected: [27]
# Predicted: [24] Expected: [27]
# Predicted: [27] Expected: [27]
# Predicted: [24] Expected: [27]
# Predicted: [6] Expected: [27]
# Predicted: [22] Expected: [27]
# Predicted: [24] Expected: [27]
# Predicted: [24] Expected: [27]
# Predicted: [27] Expected: [27]
# Predicted: [27] Expected: [27]
# Predicted: [27] Expected: [27]
# Predicted: [23] Expected: [27]
# Predicted: [12] Expected: [27]
# Predicted: [22] Expected: [27]
# Predicted: [23] Expected: [27]
# Predicted: [24] Expected: [27]
# Predicted: [27] Expected: [27]
# Predicted: [24] Expected: [27]
# Predicted: [24] Expected: [27]
# Predicted: [27] Expected: [27]
# Predicted: [23] Expected: [27]
# Predicted: [25] Expected: [27]
# Predicted: [22] Expected: [27]
# Predicted: [27] Expected: [27]
# Predicted: [27] Expected: [27]
# Predicted: [27] Expected: [27]
# Predicted: [27] Expected: [27]
# Predicted: [24] Expected: [27]
# Predicted: [23] Expected: [27]
# Predicted: [24] Expected: [27]

# %%
num = 810

# %%
test = sio.loadmat(inertial_path[num])['d_iner']

# %%
test = np.expand_dims(np.swapaxes(sequence.pad_sequences(np.swapaxes(test,1,0), maxlen= 326), 1, 0), axis =0)

# %%
pred = model.predict(test)

# %%
np.argmax(pred, axis = -1), inertial_path[num].split('/')[-1]
# Out:
# (array([25]), 'a26_s4_t1_inertial.mat')
